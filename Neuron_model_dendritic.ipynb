# %%
'''
In the following, m, h, and n are gating variables controlling the activation or inactivation of certain channels.
M is approximated as starting instantaneously, so we never need a dm/dt equation-we can just use m_inf in place of m.

This version has the dendritic component included, taken from the 2011 paper by Toparikova and Butera.
One assumption made is that total Ca^(2+) in cell is const, so we can neglect flux of Ca 2+ into or out of cell. 
Therefore, Ca_ER = (Ca_tot - Ca_i)/sig, where Ca_tot = 1.25 uM and sig = 0.185. (sig is ratio of cytosolic to ER vol.)


Helpful resources for developing this:
Code examples:
http://www.briansimulator.org/docs/examples-frompapers_Rothman_Manis_2003.html
http://www.briansimulator.org/docs/examples-misc_cable.html?highlight=dendrit
http://www.briansimulator.org/docs/librarymodels.html?highlight=dendrit
http://www.briansimulator.org/docs/examples-misc_using_classes.html

http://www.briansimulator.org/docs/examples-frompapers_Kremer_et_al_2011.html

Documents:
http://fog.ccsf.cc.ca.us/~wkaufmyn/ENGN45/Course%20Handouts/15_ElectricalProps/05_TemperatureConductivityConductor.html


'''


#number of seconds to run simulation (unitless)
runLen = 2

from brian import *
from brian.library.ionic_currents import *
import time
import inspect
from brian.compartments import *
#%matplotlib inline


#microMolar
uM = (10**-3)*mole/meter**3
#picoLitre
pL = (10**3)*(umeter**3)
#attomole
aMol = (10**-18)*mole

#start the run time clock
start = time.clock()
print "Start: ", time.strftime("%H:%M:%S")
def checkpoint():
    ellapsed = (time.clock() - start)
    print "{} sec ellapsed at {}".format(ellapsed, time.strftime("%H:%M:%S"))
    
#reinit the simulator clock so that the simulator starts at 0 seconds
defaultclock.reinit()

#---Model from 2011 Toparikova and Butera paper

EL = -57 * mvolt
EK = -85.0*mvolt
ENa = 50.0*mvolt

Cs = 21 * uF
Cd = 5 * uF

gL = 2.3 * nsiemens
gC = 1 * nsiemens
gK = 11.2 * nsiemens
gNa = 28 * nsiemens
gNaP = 2.0 * nsiemens #or 1.5 * nsiemens
gCaN = 1.5 * nsiemens

k = 0.3

#for calcium kinetics
Ca_tot = 1.25*uM
sig = 0.185 #ratio of cytosolic to ER volume
nc = 0.97
K_CaN = 0.74 * uM
fi = 0.000025
A = 0.005
K_d = 0.4 * uM
VSERCA = 400 * aMol/second #maximal SERCA pump rate
KSERCA = 0.2 #coefficient for SERCA pumps
L_IP3R = 0/37 * pL/second #ER Leak permiability
#dissociation consts. for IP3 receptor activation by IP3 and Ca2+ respectively
K_I=1*uM
K_a = 0.4*uM
P_IP3R = 31000 * pL/second
IP3 = 1 * uM

#funct. of Ca describing activation of ICaN (calcium current) by Ca2+
ICaN_active = lambda Ca: (1+(K_CaN/Ca)**nc)**-1



#constants for K and Na
thetaN = -29*mvolt
thetaM = -34*mvolt
sigmaN = -4*mvolt
sigmaM = -5*mvolt

#constants for NaP and Nap-h
thetaH = -48*mvolt
sigmaH = 6*mvolt
thetaP = -40*mvolt
sigmaP = -6*mvolt

#eqns for Na and K
mInf = lambda v: (1+exp((v-thetaM)/sigmaM))**-1
nInf = lambda v: (1+exp((v-thetaN)/sigmaN))**-1
tauMaxN = 10*ms
tauN = lambda v: tauMaxN/cosh((v-thetaN)/(2*sigmaN))

#eqns for NaP and NaP-h
hInf = lambda v: (1+exp((v-thetaH)/sigmaH))**-1
pInf = lambda v: (1+exp((v-thetaP)/sigmaP))**-1
tauMaxH = 10000*ms
tauH = lambda v: tauMaxH/cosh((v-thetaH)/(2*sigmaH))

soma = Equations('''
dVs/dt = -((gNa*(1-n)*(Vs-ENa)*m_inf**3)+ (gNaP*(Vs-ENa)*h*p_inf) + (gK*(Vs-EK)*n**4) + gL*(Vs-EL))/Cs:mvolt
#
#Sodium and Potassium Activation
m_inf = mInf(Vs):1
n_inf = nInf(Vs):1
tau_n = tauN(Vs):ms
dn/dt =  (n_inf - n)/tau_n:1
#
#sodium inactivation (nap or naph)
p_inf = pInf(Vs):1
h_inf = hInf(Vs):1
tau_h = tauH(Vs):ms
dh/dt = (h_inf - h)/tau_h:1
I:amp
''')

dendrite = Equations('''
dVd/dt = -(gCaN*ICaN_active(Ca_i)*(Vd-ENa))/Cd:mvolt
#calcium kinetics
dCa_i/dt = fi*(J_ERin-J_ERout):uM
dl/dt = A*(K_d - l*(Ca_i+K_d)):1
J_ERin = (L_IP3R + P_IP3R*(IP3*Ca_i*l/((IP3+K_I)*(Ca_i+K_a)))**3)(Ca_ER - Ca_i):aMol/second
J_ERout = VSERCA*(Ca_i**2/(KSERCA**2 + Ca_i**2)):aMol/second
Ca_ER = (Ca_tot - Ca_i)/sig:uM
I:amp
''')

Ra = (1/gC)
neuron_eqs=Compartments({'soma':soma, 'dendrite':dendrite})
neuron_eqs.connect('soma','dendrite',Ra)

#not using at moment          
eqs = '''
dVs/dt = -((gNa*(1-n)*(Vs-ENa)*m_inf**3)+ (gNaP*(Vs-ENa)*h*p_inf) + (gK*(Vs-EK)*n**4) + \
(gC/(1-k))*(Vs-Vd)+ gL*(Vs-EL))/Cs:mvolt
#
dVd/dt = (-(gCaN*ICaN_active(Ca_i)*(Vd-ENa)) - ((gC/k)*(Vd-Vs)))/Cd:mvolt
#
#Sodium and Potassium Activation
m_inf = mInf(Vs):1
n_inf = nInf(Vs):1
tau_n = tauN(Vs):ms
dn/dt =  (n_inf - n)/tau_n:1
#
#sodium inactivation (nap or naph)
p_inf = mInf_nap(Vs):1
h_inf = hInf(Vs):1
tau_h = tauH(Vs):ms
dh/dt = (h_inf - h)/tau_h:1
I:amp
#
#calcium kinetics
dCa_i/dt = fi*(J_ERin-J_ERout):uM
dl/dt = A*(Kd - l*(Ca_i+Kd)):1
J_ERin = (L_IP3R + P_IP3R*(IP3*Ca_i*l/((IP3+KI)*(Ca_i+Ka)))**3)(Ca_ER - Ca_i):aMol
J_ERout = VSERCA*(Ca_i**2/(KSERCA**2 + Ca_i**2)):aMol
Ca_ER = (Ca_tot - Ca_i)/sig:uM
'''


try:
    eq = Equations(eqs)
    #neurons=NeuronGroup(1, eqs_noNaP, clock = defaultclock)
    neurons=NeuronGroup(1, eq, order = 2, clock = defaultclock)
except DimensionMismatchError as e:
    mess = e.args[0]
    dim = e.args[1]
    print "error: ", mess, ". ",dim
    
  
    
print eq._Vm    
neurons.Vs = EL
neurons.Vd = EL
neurons.h = hInf(EL)
neurons.n = nInf(EL)
print neurons.Vd
print 
Md = StateMonitor(neurons, 'Vd', record=True)


'''
Ms = StateMonitor(neurons, 'Vs', record=True)
Md = StateMonitor(neurons, 'Vd', record=True)

checkpoint()

run(runLen*second)

checkpoint()

ps=plot(Ms.times/ms, Ms[0]/mV)
pd=plot(Md.times/ms, Md[0]/mV)
xlabel('Time (ms)')
ylabel('Membrane potential (mV)')
plt.show()

checkpoint()
'''
# Out:
# Start:  15:19:49
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-52fd8fe2cbf1> in <module>()
#     146 Ra = (1/gC)
#     147 neuron_eqs=Compartments({'soma':soma, 'dendrite':dendrite})
# --> 148 neuron_eqs.connect('soma','dendrite',Ra)
#     149
#     150 #not using at moment
#
# /Users/morganfine-morris/anaconda/lib/python2.7/site-packages/brian-1.4.1-py2.7-macosx-10.5-x86_64.egg/brian/fundamentalunits.pyc in new_f(*args, **kwds)
#    1406                                                      str(au[k]),
#    1407                                                      get_dimensions(newkeyset[k]))
# -> 1408             result = f(*args, **kwds)
#    1409             if "result" in au:
#    1410                 assert have_same_dimensions(result, au["result"]), \
#
# /Users/morganfine-morris/anaconda/lib/python2.7/site-packages/brian-1.4.1-py2.7-macosx-10.5-x86_64.egg/brian/compartments.pyc in connect(self, a, b, Ra)
#      67         self += Equations('Ia=(va-vb)*invRa : amp', Ia=Ia_name, invRa=1. / Ra, va='vm_' + a, vb='vm_' + b)
#      68         # Add the current to both compartments
# ---> 69         self._string['__membrane_Im_' + a] += '-' + Ia_name
#      70         self._string['__membrane_Im_' + b] += '+' + Ia_name
#
# KeyError: '__membrane_Im_soma'

# %%
test =  MembraneEquation(Cs*meter**2)
print "membrane eq: ",test
print test.Cs
# Out:
# membrane eq:  dvm/dt = __membrane_Im/C [diffeq]
# __membrane_Im = 0*unit [eq]
#
# <function <lambda> at 0x1080768c0>
