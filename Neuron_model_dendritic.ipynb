# %%
'''
In the following, m, h, and n are gating variables controlling the activation or inactivation of certain channels.
M is approximated as starting instantaneously, so we never need a dm/dt equation-we can just use m_inf in place of m.

This version has the dendritic component included, taken from the 2011 paper by Toparikova and Butera.
One assumption made is that total Ca^(2+) in cell is const, so we can neglect flux of Ca 2+ into or out of cell. 
Therefore, Ca_ER = (Ca_tot - Ca_i)/sig, where Ca_tot = 1.25 uM and sig = 0.185. (sig is ratio of cytosolic to ER vol.)


Helpful resources for developing this:
Code examples:
http://www.briansimulator.org/docs/examples-frompapers_Rothman_Manis_2003.html
http://www.briansimulator.org/docs/examples-misc_cable.html?highlight=dendrit
http://www.briansimulator.org/docs/librarymodels.html?highlight=dendrit
http://www.briansimulator.org/docs/examples-misc_using_classes.html

http://www.briansimulator.org/docs/examples-frompapers_Kremer_et_al_2011.html

Documents:
http://fog.ccsf.cc.ca.us/~wkaufmyn/ENGN45/Course%20Handouts/15_ElectricalProps/05_TemperatureConductivityConductor.html


'''


#number of seconds to run simulation (unitless)
runLen = 2

from brian import *
from brian.library.ionic_currents import *
import time
import inspect
from brian.compartments import *
#%matplotlib inline


#microMolar
uM = (10**-3)*mole/meter**3
#picoLitre
pL = (10**3)*(umeter**3)
#attomole
aMol = (10**-18)*mole

#start the run time clock
start = time.clock()
print "Start: ", time.strftime("%H:%M:%S")
def checkpoint():
    ellapsed = (time.clock() - start)
    print "{} sec ellapsed at {}".format(ellapsed, time.strftime("%H:%M:%S"))
    
#reinit the simulator clock so that the simulator starts at 0 seconds
defaultclock.reinit()

#---Model from 2011 Toparikova and Butera paper

EL = -57 * mvolt
EK = -85.0*mvolt
ENa = 50.0*mvolt

Cs = 21 * uF
Cd = 5 * uF

gL = 2.3 * nsiemens
gC = 1.0 * nsiemens
gK = 11.2 * nsiemens
gNa = 28 * nsiemens
gNaP = 2.0 * nsiemens #or 1.5 * nsiemens
gCaN = 1.5 * nsiemens

#constants for K and Na
thetaN = -29*mvolt
thetaM = -34*mvolt
sigmaN = -4*mvolt
sigmaM = -5*mvolt

#constants for NaP and Nap-h
thetaH = -48*mvolt
sigmaH = 6*mvolt
thetaP = -40*mvolt
sigmaP = -6*mvolt

#eqns for Na and K
mInf = lambda v: (1+exp((v-thetaM)/sigmaM))**-1
nInf = lambda v: (1+exp((v-thetaN)/sigmaN))**-1
tauMaxN = 10*ms
tauN = lambda v: tauMaxN/cosh((v-thetaN)/(2*sigmaN))

#eqns for NaP and NaP-h
hInf = lambda v: (1+exp((v-thetaH)/sigmaH))**-1
pInf = lambda v: (1+exp((v-thetaP)/sigmaP))**-1
tauMaxH = 10000*ms
tauH = lambda v: tauMaxH/cosh((v-thetaH)/(2*sigmaH))

soma = Equations('''
dVs/dt = -((gNa*(1-n)*(Vs-ENa)*m_inf**3)+ (gNaP*(Vs-ENa)*h*p_inf) + (gK*(Vs-EK)*n**4) + gL*(Vs-EL))/Cs:mvolt
#
#Sodium and Potassium Activation
m_inf = mInf(Vs):1
n_inf = nInf(Vs):1
tau_n = tauN(Vs):ms
dn/dt =  (n_inf - n)/tau_n:1
#
#sodium inactivation (nap or naph)
p_inf = pInf(Vs):1
h_inf = hInf(Vs):1
tau_h = tauH(Vs):ms
dh/dt = (h_inf - h)/tau_h:1
I:amp
''')
print soma

#for calcium kinetics
k = 0.3
#funct. of Ca describing activation of ICaN (calcium current) by Ca2+. Called f([Ca]_{i}) in paper
ICaN_active = lambda Ca: (1+(K_CaN/Ca)**nc)**-1
nc = 0.97
K_CaN = 0.74 * uM

fi = 0.000025
A = 0.005

L_IP3R = 0/37 * pL/second #ER Leak permiability
P_IP3R = 31000 * pL/second
IP3 = 1 * uM
#dissociation consts. for IP3 receptor activation by IP3 and Ca2+ respectively
K_I= 1.0 * uM
K_a = 0.4 * uM
K_d = 0.4 * uM
VSERCA = 400 * aMol/second #maximal SERCA pump rate
KSERCA = 0.2 #coefficient for SERCA pumps
#for calc [Ca]_{ER}
Ca_tot = 1.25*uM
sig = 0.185 #ratio of cytosolic to ER volume

dendrite = Equations('''
dVd/dt = -(gCaN*ICaN_active(Ca_i)*(Vd-ENa))/Cd:mvolt
#calcium kinetics
dCa_i/dt = fi*(J_ERin-J_ERout):uM
dl/dt = A*(K_d - l*(Ca_i+K_d)):1
J_ERin = (L_IP3R + P_IP3R*(IP3*Ca_i*l/((IP3+K_I)*(Ca_i+K_a)))**3)(Ca_ER - Ca_i):aMol/second
J_ERout = VSERCA*(Ca_i**2/(KSERCA**2 + Ca_i**2)):aMol/second
Ca_ER = (Ca_tot - Ca_i)/sig:uM
I:amp
''')
print dendrite

# %%
Ra = (1/gC)
neuron_eqs=Compartments({'soma':soma, 'dendrite':dendrite})
neuron_eqs.connect('soma','dendrite',Ra)

try:
    eq = Equations(eqs)
    #neurons=NeuronGroup(1, eqs_noNaP, clock = defaultclock)
    neurons=NeuronGroup(1, eq, order = 2, clock = defaultclock)
except DimensionMismatchError as e:
    mess = e.args[0]
    dim = e.args[1]
    print "error: ", mess, ". ",dim
    
  
    
print eq._Vm    
neurons.Vs = EL
neurons.Vd = EL
neurons.h = hInf(EL)
neurons.n = nInf(EL)
print neurons.Vd
print 
Md = StateMonitor(neurons, 'Vd', record=True)


'''
Ms = StateMonitor(neurons, 'Vs', record=True)
Md = StateMonitor(neurons, 'Vd', record=True)

checkpoint()

run(runLen*second)

checkpoint()

ps=plot(Ms.times/ms, Ms[0]/mV)
pd=plot(Md.times/ms, Md[0]/mV)
xlabel('Time (ms)')
ylabel('Membrane potential (mV)')
plt.show()

checkpoint()
'''
# Out:
# /Users/morganfine-morris/anaconda/lib/python2.7/site-packages/brian-1.4.1-py2.7-macosx-10.5-x86_64.egg/brian/utils/sparse_patch/__init__.py:39: UserWarning: Couldn't find matching sparse matrix patch for scipy version 0.14.0, but in most cases this shouldn't be a problem.
#   warnings.warn("Couldn't find matching sparse matrix patch for scipy version %s, but in most cases this shouldn't be a problem." % scipy.__version__)
# /Users/morganfine-morris/anaconda/lib/python2.7/site-packages/nose/plugins/manager.py:418: UserWarning: Module readline was already imported from /Users/morganfine-morris/anaconda/python.app/Contents/lib/python2.7/lib-dynload/readline.so, but /Users/morganfine-morris/anaconda/lib/python2.7/site-packages is being added to sys.path
#   import pkg_resources
# Start:  12:46:44
# dVs/dt = -((gNa*(1-n)*(Vs-ENa)*m_inf**3)+ (gNaP*(Vs-ENa)*h*p_inf) + (gK*(Vs-EK)*n**4) + gL*(Vs-EL))/Cs [diffeq]
# dn/dt = (n_inf - n)/tau_n [diffeq]
# dh/dt = (h_inf - h)/tau_h [diffeq]
# dI/dt = 0*amp/second [diffeq]
# m_inf = mInf(Vs) [eq]
# n_inf = nInf(Vs) [eq]
# tau_n = tauN(Vs) [eq]
# p_inf = pInf(Vs) [eq]
# h_inf = hInf(Vs) [eq]
# tau_h = tauH(Vs) [eq]
# dVd/dt = -(gCaN*ICaN_active(Ca_i)*(Vd-ENa))/Cd [diffeq]
# dCa_i/dt = fi*(J_ERin-J_ERout) [diffeq]
# dl/dt = A*(K_d - l*(Ca_i+K_d)) [diffeq]
# dI/dt = 0*amp/second [diffeq]
# J_ERin = (L_IP3R + P_IP3R*(IP3*Ca_i*l/((IP3+K_I)*(Ca_i+K_a)))**3)(Ca_ER - Ca_i) [eq]
# J_ERout = VSERCA*(Ca_i**2/(KSERCA**2 + Ca_i**2)) [eq]
# Ca_ER = (Ca_tot - Ca_i)/sig [eq]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-fb327eadd4d7> in <module>()
#     149 Ra = (1/gC)
#     150 neuron_eqs=Compartments({'soma':soma, 'dendrite':dendrite})
# --> 151 neuron_eqs.connect('soma','dendrite',Ra)
#
# /Users/morganfine-morris/anaconda/lib/python2.7/site-packages/brian-1.4.1-py2.7-macosx-10.5-x86_64.egg/brian/fundamentalunits.pyc in new_f(*args, **kwds)
#    1406                                                      str(au[k]),
#    1407                                                      get_dimensions(newkeyset[k]))
# -> 1408             result = f(*args, **kwds)
#    1409             if "result" in au:
#    1410                 assert have_same_dimensions(result, au["result"]), \
#
# /Users/morganfine-morris/anaconda/lib/python2.7/site-packages/brian-1.4.1-py2.7-macosx-10.5-x86_64.egg/brian/compartments.pyc in connect(self, a, b, Ra)
#      67         self += Equations('Ia=(va-vb)*invRa : amp', Ia=Ia_name, invRa=1. / Ra, va='vm_' + a, vb='vm_' + b)
#      68         # Add the current to both compartments
# ---> 69         self._string['__membrane_Im_' + a] += '-' + Ia_name
#      70         self._string['__membrane_Im_' + b] += '+' + Ia_name
#
# KeyError: '__membrane_Im_soma'

# %%
eqs=MembraneEquation(200*pF)+IonicCurrent('I=(vm-V0)/R : amp')
print eqs
current=leak_current(gl=10*nS,El=-70*mV,current_name='I')
print current
# Out:
# dvm/dt = __membrane_Im/C [diffeq]
# I = (vm-V0)/R [eq]
# __current_I = -I [eq]
# __membrane_Im = __current_I [eq]
#
# I = gl*(El-vm) [eq]
# __current_I = I [eq]

# %%
from brian import *
from brian.library.ionic_currents import *
#The nominal params for leak current are gL=2.8 nS and EL=-65 mV.
EL = -57*mvolt
EK = -85.0*mvolt
ENa = 50.0*mvolt
C = 21 * pF
gL = 2.8*nsiemens
gK = 11.2*nsiemens
gNa = 28*nsiemens
gNaP = 2.8*nsiemens

#---Model 1 of butera99a
#---time constants are consistent for all currents in Model 1 of butera99a
tauMaxH = 10000*ms
tauMaxN = 10*ms

#constants for K and Na
thetaN = -29*mvolt
thetaM = -34*mvolt
sigmaN = -4*mvolt
sigmaM = -5*mvolt

#constants for NaP and Nap-h
thetaH = -48*mvolt
sigmaH = 6*mvolt
thetaP = -40*mvolt
sigmaP = -6*mvolt

#eqns for Na and K
mInf = lambda v: (1+exp((v-thetaM)/sigmaM))**-1
nInf = lambda v: (1+exp((v-thetaN)/sigmaN))**-1
tauN = lambda v: tauMaxN/cosh((v-thetaN)/(2*sigmaN))

#eqns for NaP and NaP-h
hInf = lambda v: (1+exp((v-thetaH)/sigmaH))**-1
pInf = lambda v: (1+exp((v-thetaP)/sigmaP))**-1
tauH = lambda v: tauMaxH/cosh((v-thetaH)/(2*sigmaH))

#no nap - this one seems to be correct
eqs = '''
dV/dt = -((gNa*(1-n)*(V-ENa)*m_Inf**3)+ (gNaP*(V-ENa)*h*p_Inf) + \
(gK*(V-EK)*n**4) + gL*(V-EL))/C:mvolt
#
#Sodium and Potassium Activation
m_Inf = mInf(V):1
n_inf = nInf(V):1
tau_n = tauN(V):ms
dn/dt = (n_inf - n)/tau_n:1
#
#sodium inactivation (nap or naph)
p_Inf = pInf(V):1
h_inf = hInf(V):1
tau_h = tauH(V):ms
dh/dt = (h_inf - h)/tau_h:1
I:amp
'''
eqObj = Equations(eqs)
#soma equation
eS = MembraneEquation(C, vm="Vs") + IonicCurrent('ILeak=gL*(Vs-EL) : amp')
eS += IonicCurrent('INa=(gNa*(1-n)*(Vs-ENa)*m_inf**3) : amp')
eS += IonicCurrent('INaPh=(gNaP*(Vs-ENa)*h*p_inf) : amp')
eS += IonicCurrent('IK=(gK*(Vs-EK)*n**4) : amp')
eS += Equations(''' 
#Sodium and Potassium Activation
m_inf = mInf(Vs):1
n_inf = nInf(Vs):1
tau_n = tauN(Vs):ms
dn/dt =  (n_inf - n)/tau_n:1
#sodium inactivation (nap or naph)
p_inf = pInf(Vs):1
h_inf = hInf(Vs):1
tau_h = tauH(Vs):ms
dh/dt = (h_inf - h)/tau_h:1
I:amp
''')

soma = Equations('''
dVs/dt = -((gNa*(1-n)*(Vs-ENa)*m_inf**3)+ (gNaP*(Vs-ENa)*h*p_inf) + (gK*(Vs-EK)*n**4) + gL*(Vs-EL))/C:mvolt
#
#Sodium and Potassium Activation
m_inf = mInf(Vs):1
n_inf = nInf(Vs):1
tau_n = tauN(Vs):ms
dn/dt =  (n_inf - n)/tau_n:1
#
#sodium inactivation (nap or naph)
p_inf = pInf(Vs):1
h_inf = hInf(Vs):1
tau_h = tauH(Vs):ms
dh/dt = (h_inf - h)/tau_h:1
I:amp
''')

print "eqObj: \n",eqObj
print "eS: \n",eS
print "Soma:\n",soma
#reinit the simulator clock so that the simulator starts at 0 second
defaultclock.reinit()
neurons=NeuronGroup(1, eS, order = 2, clock = defaultclock)
    
neurons.Vs = EL
neurons.h = hInf(EL)
neurons.n = nInf(EL)
print 
M = StateMonitor(neurons, 'Vs', record=True)
run(2*second)
#checkpoint()
pd=plot(M.times/ms, M[0]/mvolt)
#xlabel('Time (ms)')
#ylabel('Membrane potential (mV)')
plt.show()
# Out:
# dV/dt = -((gNa*(1-n)*(V-ENa)*m_Inf**3)+ (gNaP*(V-ENa)*h*p_Inf) + (gK*(V-EK)*n**4) + gL*(V-EL))/C [diffeq]
# dn/dt = (n_inf - n)/tau_n [diffeq]
# dh/dt = (h_inf - h)/tau_h [diffeq]
# dI/dt = 0*amp/second [diffeq]
# m_Inf = mInf(V) [eq]
# n_inf = nInf(V) [eq]
# tau_n = tauN(V) [eq]
# p_Inf = pInf(V) [eq]
# h_inf = hInf(V) [eq]
# tau_h = tauH(V) [eq]
